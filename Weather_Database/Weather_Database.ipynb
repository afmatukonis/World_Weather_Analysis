# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 783

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_describe = city_weather["weather"][0]["description"] 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# City not found. Skipping...
# Processing Record 2 of Set 1 | karpogory
# City not found. Skipping...
# Processing Record 3 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | hami
# City not found. Skipping...
# Processing Record 6 of Set 1 | camocim
# City not found. Skipping...
# Processing Record 7 of Set 1 | bambous virieux
# City not found. Skipping...
# Processing Record 8 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 9 of Set 1 | poum
# City not found. Skipping...
# Processing Record 10 of Set 1 | najran
# City not found. Skipping...
# Processing Record 11 of Set 1 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 12 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 13 of Set 1 | tessalit
# City not found. Skipping...
# Processing Record 14 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 15 of Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 3 of Set 12 | boca do acre
# City not found. Skipping...
# Processing Record 4 of Set 12 | christchurch
# City not found. Skipping...
# Processing Record 5 of Set 12 | blackfoot
# City not found. Skipping...
# Processing Record 6 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 12 | le vauclin
# City not found. Skipping...
# Processing Record 8 of Set 12 | kununurra
# City not found. Skipping...
# Processing Record 9 of Set 12 | tucuman
# City not found. Skipping...
# Processing Record 10 of Set 12 | dandong
# City not found. Skipping...
# Processing Record 11 of Set 12 | grand gaube
# City not found. Skipping...
# Processing Record 12 of Set 12 | cardston
# City not found. Skipping...
# Processing Record 13 of Set 12 | nibbar
# City not found. Skipping...
# Processing Record 14 of Set 12 | hatillo
# City not found. Skipping...
# Processing Record 15 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 12 | barcelos
# City not found. Skipping...
# Processing Record 18 of Set 12 | synya
# City not found. Skipping...
# Processing Record 19 of Set 12 | isangel
# City not found. Skipping...
# Processing Record 20 of Set 12 | opuwo
# City not found. Skipping...
# Processing Record 21 of Set 12 | sinnamary
# City not found. Skipping...
# Processing Record 22 of Set 12 | calabozo
# City not found. Skipping...
# Processing Record 23 of Set 12 | zabaykalsk
# City not found. Skipping...
# Processing Record 24 of Set 12 | teguise
# City not found. Skipping...
# Processing Record 25 of Set 12 | ambovombe
# City not found. Skipping...
# Processing Record 26 of Set 12 | sumbe
# City not found. Skipping...
# Processing Record 27 of Set 12 | skibbereen
# City not found. Skipping...
# Processing Record 28 of Set 12 | antofagasta
# City not found. Skipping...
# Processing Record 29 of Set 12 | le port
# City not found. Skipping...
# Processing Record 30 of Set 12 | amapa
# City not found. Skipping...
# Processing Record 31 of Set 12 | tilichiki
# City not found. Skipping...
# Processing Record 32 of Set 12 | kimbe
# City not found. Skipping...
# Processing Record 33 of Set 12 | torrington
# City not found. Skipping...
# Processing Record 34 of Set 12 | tecoanapa
# City not found. Skipping...
# Processing Record 35 of Set 12 | hammerfest
# City not found. Skipping...
# Processing Record 36 of Set 12 | waitati
# City not found. Skipping...
# Processing Record 37 of Set 12 | haapu
# City not found. Skipping...
# Processing Record 38 of Set 12 | burnie
# City not found. Skipping...
# Processing Record 39 of Set 12 | uusikaupunki
# City not found. Skipping...
# Processing Record 40 of Set 12 | sao francisco
# City not found. Skipping...
# Processing Record 41 of Set 12 | ambilobe
# City not found. Skipping...
# Processing Record 42 of Set 12 | bambanglipuro
# City not found. Skipping...
# Processing Record 43 of Set 12 | baruun-urt
# City not found. Skipping...
# Processing Record 44 of Set 12 | yaan
# City not found. Skipping...
# Processing Record 45 of Set 12 | ranfurly
# City not found. Skipping...
# Processing Record 46 of Set 12 | dickinson
# City not found. Skipping...
# Processing Record 47 of Set 12 | maltahohe
# City not found. Skipping...
# Processing Record 48 of Set 12 | tabuk
# City not found. Skipping...
# Processing Record 49 of Set 12 | mindelo
# City not found. Skipping...
# Processing Record 50 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record
# Processing Record 49 of Set 13 | nemuro
# City not found. Skipping...
# Processing Record 50 of Set 13 | kyzyl-suu
# City not found. Skipping...
# Processing Record 1 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 14 | garden city
# Processing Record 3 of Set 14 | bandarbeyla
# Processing Record 4 of Set 14 | charters towers
# Processing Record 5 of Set 14 | mitsamiouli
# Processing Record 6 of Set 14 | aquin
# Processing Record 7 of Set 14 | turukhansk
# Processing Record 8 of Set 14 | buribay
# Processing Record 9 of Set 14 | nata
# Processing Record 10 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 14 | rockland
# Processing Record 12 of Set 14 | darnah
# Processing Record 13 of Set 14 | mizur
# Processing Record 14 of Set 14 | quelimane
# Processing Record 15 of Set 14 | jieshi
# Processing Record 16 of Set 14 | filadelfia
# Processing Record 17 of Set 14 | bulawayo
# Processing Record 18 of Set 14 | namatanai
# Processing Record 19 of Set 14 | treinta y tres
# Processing Record 20 of Set 14 | ostrovnoy
# Processing Record 21 of Set 14 | saryozek
# Processing Record 22 of Set 14 | vilhena
# Processing Record 23 of Set 14 | cefalu
# Processing Record 24 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 25 of Set 14 | kyra
# Processing Record 26 of Set 14 | bubaque
# Processing Record 27 of Set 14 | ixtapa
# Processing Record 28 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 14 | west plains
# Processing Record 31 of Set 14 | bourail
# Processing Record 32 of Set 14 | ponnani
# Processing Record 33 of Set 14 | takaka
# Processing Record 34 of Set 14 | dese
# Processing Record 35 of Set 14 | dakar
# Processing Record 36 of Set 14 | mach
# Processing Record 37 of Set 14 | rudraprayag
# Processing Record 38 of Set 14 | malanville
# Processing Record 39 of Set 14 | lashio
# Processing Record 40 of Set 14 | santa marta
# Processing Record 41 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 14 | nelson bay
# Processing Record 43 of Set 14 | salina cruz
# Processing Record 44 of Set 14 | idah
# Processing Record 45 of Set 14 | kichmengskiy gorodok
# Processing Record 46 of Set 14 | sivas
# Processing Record 47 of Set 14 | hilton head island
# Processing Record 48 of Set 14 | manaus
# Processing Record 49 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 50 of Set 14 | nyagan
# Processing Record 1 of Set 15 | benghazi
# Processing Record 2 of Set 15 | kohlu
# Processing Record 3 of Set 15 | farah
# Processing Record 4 of Set 15 | tomatlan
# Processing Record 5 of Set 15 | virginia beach
# Processing Record 6 of Set 15 | baykit
# Processing Record 7 of Set 15 | viedma
# Processing Record 8 of Set 15 | banihal
# Processing Record 9 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 15 | paracuru
# Processing Record 11 of Set 15 | bam
# Processing Record 12 of Set 15 | sept-iles
# Processing Record 13 of Set 15 | pietarsaari
# Processing Record 14 of Set 15 | okhotsk
# Processing Record 15 of Set 15 | davila
# Processing Record 16 of Set 15 | timizart
# Processing Record 17 of Set 15 | jackson
# Processing Record 18 of Set 15 | ha giang
# Processing Record 19 of Set 15 | iwanai
# Processing Record 20 of Set 15 | livenka
# Processing Record 21 of Set 15 | hayden
# Processing Record 22 of Set 15 | vanimo
# Processing Record 23 of Set 15 | vanavara
# Processing Record 24 of Set 15 | matara
# Processing Record 25 of Set 15 | roebourne
# Processing Record 26 of Set 15 | kismayo
# Processing Record 27 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 15 | pacific grove
# Processing Record 29 of Set 15 | bogorodskoye
# Processing Record 30 of Set 15 | rafaela
# Processing Record 31 of Set 15 | lingyuan
# Processing Record 32 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 15 | ikeda
# Processing Record 34 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 35 of Set 15 | roma
# Processing Record 36 of Set 15 | castelldefels
# Processing Record 37 of Set 15 | knysna
# Processing Record 38 of Set 15 | wajid
# Processing Record 39 of Set 15 | plaster rock
# Processing Record 40 of Set 15 | nouadhibou
# Processing Record 41 of Set 15 | cervo
# Processing Record 42 of Set 15 | yamachiche
# Processing Record 43 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 44 of Set 15 | bereda
# Processing Record 45 of Set 15 | fort-shevchenko
# Processing Record 46 of Set 15 | trelew
# Processing Record 47 of Set 15 | batsfjord
# Processing Record 48 of Set 15 | tortosa
# Processing Record 49 of Set 15 | okha
# Processing Record 50 of Set 15 | seduva
# Processing Record 1 of Set 16 | mpika
# Processing Record 2 of Set 16 | marienburg
# Processing Record 3 of Set 16 | benguela
# Processing Record 4 of Set 16 | half moon bay
# Processing Record 5 of Set 16 | baiyin
# Processing Record 6 of Set 16 | pangnirtung
# Processing Record 7 of Set 16 | chapais
# Processing Record 8 of Set 16 | ust-tsilma
# Processing Record 9 of Set 16 | vrangel
# Processing Record 10 of Set 16 | cordoba
# Processing Record 11 of Set 16 | kelvington
# Processing Record 12 of Set 16 | mariental
# Processing Record 13 of Set 16 | hofn
# Processing Record 14 of Set 16 | waingapu
# Processing Record 15 of Set 16 | bathsheba
# Processing Record 16 of Set 16 | nianzishan
# Processing Record 17 of Set 16 | darhan
# Processing Record 18 of Set 16 | makakilo city
# Processing Record 19 of Set 16 | moyale
# Processing Record 20 of Set 16 | never
# Processing Record 21 of Set 16 | port hawkesbury
# Processing Record 22 of Set 16 | jawhar
# Processing Record 23 of Set 16 | konstantinovka
# Processing Record 24 of Set 16 | mangrol
# Processing Record 25 of Set 16 | dunedin
# Processing Record 26 of Set 16 | mazurivka
# Processing Record 27 of Set 16 | odweyne
# Processing Record 28 of Set 16 | catalina
# Processing Record 29 of Set 16 | angra
# City not found. Skipping...
# Processing Record 30 of Set 16 | atherton
# Processing Record 31 of Set 16 | winneba
# Processing Record 32 of Set 16 | cah ab
# City not found. Skipping...
# Processing Record 33 of Set 16 | gat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 119

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Garden City  42.3256  -83.3310    283.68        99         100
# 1      Bandarbeyla   9.4942   50.8122    299.53        64          24
# 2  Charters Towers -20.1000  146.2667    300.11        48          97
# 3      Mitsamiouli -11.3847   43.2844    299.31        83          75
# 4            Aquin  18.2833  -73.4000    295.36        81           5
# 5       Turukhansk  65.8167   87.9833    244.40        93          95
# 6          Buribay  51.9617   58.1592    273.61        97         100
# 7             Nata   8.3333  -80.5167    295.39        89          54
# 8         Rockland  41.1668  -74.0496    286.89        97         100
# 9           Darnah  32.7670   22.6367    290.02        61          69
#
#    Wind Speed Country Current Description
# 0        0.00      US                 fog
# 1       10.07      SO          few clouds
# 2        6.26      AU     overcast clouds
# 3        4.12      KM         shower rain
# 4        1.61      HT           clear sky
# 5        2.99      RU     overcast clouds
# 6        7.52      RU     overcast clouds
# 7        2.36      PA       broken clouds
# 8        3.01      US     overcast clouds
# 9        6.53      LY       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_database_df = city_data_df[new_column_order]

# Display sample data
city_database_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Garden City      US  42.3256  -83.3310    283.68        99         100
# 1      Bandarbeyla      SO   9.4942   50.8122    299.53        64          24
# 2  Charters Towers      AU -20.1000  146.2667    300.11        48          97
# 3      Mitsamiouli      KM -11.3847   43.2844    299.31        83          75
# 4            Aquin      HT  18.2833  -73.4000    295.36        81           5
# 5       Turukhansk      RU  65.8167   87.9833    244.40        93          95
# 6          Buribay      RU  51.9617   58.1592    273.61        97         100
# 7             Nata      PA   8.3333  -80.5167    295.39        89          54
# 8         Rockland      US  41.1668  -74.0496    286.89        97         100
# 9           Darnah      LY  32.7670   22.6367    290.02        61          69
#
#    Wind Speed Current Description
# 0        0.00                 fog
# 1       10.07          few clouds
# 2        6.26     overcast clouds
# 3        4.12         shower rain
# 4        1.61           clear sky
# 5        2.99     overcast clouds
# 6        7.52     overcast clouds
# 7        2.36       broken clouds
# 8        3.01     overcast clouds
# 9        6.53       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_database_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_database_df.to_csv(output_data_file, index_label="City_ID")
